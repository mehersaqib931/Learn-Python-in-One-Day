# %%
x = 7
y = 9

# %% [markdown]
# ![op2-1-528x221.png](attachment:op2-1-528x221.png)

# %%
# addition

# %%
x + y
# Out:
# 16

# %%
# subtraction

# %%
x -y
# Out:
# -2

# %%
x * y
# Out:
# 63

# %%
x / y
# Out:
# 0.7777777777777778

# %%
 x % y
# Out:
# 7

# %%
x**y
# Out:
# 40353607

# %%
x //y
# Out:
# 0
